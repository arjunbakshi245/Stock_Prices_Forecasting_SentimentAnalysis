# %%
import pandas as pd
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
lstm = pd.read_csv('LSTM_14_1.csv')
gru  = pd.read_csv('GRU_with_sentiment_14_3day.csv')
real = pd.read_csv('orgi.csv') 
lstm_P = pd.read_csv('LSTM_14.csv')
gru_P = pd.read_csv('GRU_14.csv')

# %%
lstm.columns = ['Unnamed: 0', 'Date', 'Open_lstm']
gru.columns = ['Unnamed: 0', 'Date', 'Open_gru']
lstm_P.columns = ['Unnamed: 0', 'Date', 'Open_lstm_P']
gru_P.columns = ['Unnamed: 0', 'Date', 'Open_gru_P']

# %%
result_1 = pd.merge(lstm, gru, how="inner", on=["Date"])
res = pd.merge(lstm_P, gru_P, how="inner", on=["Date"])
result_14 = pd.merge(result_1, res, how="inner", on=["Date"])
final = pd.merge(real,result_14, how="inner", on=["Date"])

# %%
final.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-01-29  13946.599609  13966.849609  13596.750000  13634.599609
# 1  2021-02-01  13758.599609  14336.349609  13661.750000  14281.200195
# 2  2021-02-02  14481.099609  14731.700195  14469.150391  14647.849609
# 3  2021-02-03  14754.900391  14868.849609  14574.150391  14789.950195
# 4  2021-02-04  14789.049805  14913.700195  14714.750000  14895.650391
#
#       Adj Close  Volume  Unnamed: 0_x_x  Open_lstm  Unnamed: 0_y_x  \
# 0  13634.599609  753200               0  13788.588               0
# 1  14281.200195  870500               3  13994.577               3
# 2  14647.849609  915000               4  14034.522               4
# 3  14789.950195  869500               5  13987.270               5
# 4  14895.650391  884700               6  13967.406               6
#
#      Open_gru  Unnamed: 0_x_y  Open_lstm_P  Unnamed: 0_y_y  Open_gru_P
# 0  13763.9720               0    13646.228               0   13422.086
# 1  13907.7295               3    13835.412               3   13606.012
# 2  13935.2670               4    13881.149               4   13622.289
# 3  13848.6150               5    13832.153               5   13432.317
# 4  13807.9540               6    13822.406               6   13396.591

# %%
lstm_data = final['Open_lstm']
gru_dat = final['Open_gru']
lstm_Pdata = final['Open_lstm_P']
gru_Pdata = final['Open_gru_P']
real_data = final['Open']

# %%
sns.set( rc={'figure.figsize':(15.7,8.27)})
sns.lineplot(final['Date'], final['Open'], color = 'red' , label = 'Actual')
sns.lineplot(final['Date'], final['Open_gru'], color = 'green' , label = 'GRU - 3day')
sns.lineplot(final['Date'], final['Open_lstm'] , color = 'blue' , label = 'LSTM - 1week')
sns.lineplot(final['Date'], final['Open_lstm_P'] , color = 'yellow' , label = 'LSTM Plain')
sns.lineplot(final['Date'], final['Open_gru_P'] , color = 'black' , label = 'GRU PLain')
plt.title("14day window Comparisons" , size =24)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, '14day window Comparisons')

# %%
#Plot a line graph
plt.plot(final['Open_lstm'], label='LSTM 14 day window-1 week Lagged')
plt.plot(final['Open_gru'], label='GRU 14 day window-3 days lagged')
plt.plot(final['Open'], label='Actual')

 
# Add labels and title
plt.title("7 day window Comparisons")
plt.xlabel("Date")
plt.ylabel("Open")
 
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-227b95162a8a> in <module>
#       1 #Plot a line graph
# ----> 2 plt.plot(final['Open_lstm'], label='LSTM 14 day window-1 week Lagged')
#       3 plt.plot(final['Open_gru'], label='GRU 14 day window-3 days lagged')
#       4 plt.plot(final['Open'], label='Actual')
#       5
#
# NameError: name 'final' is not defined
